# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D,
    Flatten, Dense, Dropout
)
from tensorflow.keras.optimizers import Adam

# %%
train_dir = "../data/split/train"
val_dir   = "../data/split/val"
test_dir  = "../data/split/test"

IMG_SIZE = 224

# %%
def load_data(base_dir):
    X = []
    y = []
    
    for label, cls in enumerate(["Normal", "TB"]):
        class_dir = os.path.join(base_dir, cls)
        
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            
            if img is None:
                continue
            
            img = img / 255.0
            img = np.expand_dims(img, axis=-1)
            
            X.append(img)
            y.append(label)
    
    return np.array(X), np.array(y)

# %%
X_train, y_train = load_data(train_dir)
X_val, y_val     = load_data(val_dir)
X_test, y_test   = load_data(test_dir)

X_train.shape, y_train.shape
# Out:
# ((2940, 224, 224, 1), (2940,))

# %%
print("Train TB:", np.sum(y_train == 1))
print("Train Normal:", np.sum(y_train == 0))
# Out:
# Train TB: 490
# Train Normal: 2450

# %%
from tensorflow.keras.layers import Input

model = Sequential([
    Input(shape=(224, 224, 1)),

    Conv2D(32, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(1, activation="sigmoid")
])

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=10,
    batch_size=16
)
# Out:
# --------------------------------------------------------------
# ValueError                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 history = model.fit(
#       2     X_train, y_train,
#       3     validation_data=(X_val, y_val),
#       4     epochs=10,
#       5     batch_size=16
#       6 )
#
# File ~\OneDrive\Documents\tb_ai_project\venv\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\OneDrive\Documents\tb_ai_project\venv\lib\site-packages\keras\src\trainers\trainer.py:1058, in Trainer._assert_compile_called(self, method_name)
#    1056 else:
#    1057     msg += f"calling `{method_name}()`."
# -> 1058 raise ValueError(msg)
#
# ValueError: You must call `compile()` before using the model.

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
model.optimizer

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=10,
    batch_size=16
)
# Out:
# Epoch 1/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 240s 1s/step - accuracy: 0.8694 - loss: 0.3158 - val_accuracy: 0.9222 - val_loss: 0.1928
# Epoch 2/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 231s 1s/step - accuracy: 0.9293 - loss: 0.1775 - val_accuracy: 0.9508 - val_loss: 0.1469
# Epoch 3/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9320 - loss: 0.1518 - val_accuracy: 0.9571 - val_loss: 0.1225
# Epoch 4/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9514 - loss: 0.1304 - val_accuracy: 0.9667 - val_loss: 0.1077
# Epoch 5/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.9565 - loss: 0.1121 - val_accuracy: 0.9714 - val_loss: 0.0989
# Epoch 6/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.9629 - loss: 0.0959 - val_accuracy: 0.9667 - val_loss: 0.0949
# Epoch 7/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9687 - loss: 0.0847 - val_accuracy: 0.9540 - val_loss: 0.1231
# Epoch 8/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.9707 - loss: 0.0800 - val_accuracy: 0.9651 - val_loss: 0.0947
# Epoch 9/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.9718 - loss: 0.0760 - val_accuracy: 0.9714 - val_loss: 0.0879
# Epoch 10/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.9786 - loss: 0.0616 - val_accuracy: 0.9698 - val_loss: 0.0804

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step - accuracy: 0.9794 - loss: 0.0713
# Test Loss: 0.07125826925039291
# Test Accuracy: 0.9793650507926941

# %%
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[520,   5],
#        [  8,  97]])

# %%
TN, FP, FN, TP = cm.ravel()

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)

print("Sensitivity (TB recall):", sensitivity)
print("Specificity (Normal recall):", specificity)
# Out:
# Sensitivity (TB recall): 0.9238095238095239
# Specificity (Normal recall): 0.9904761904761905

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=["Normal", "TB"]))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.99      0.99       525
#           TB       0.95      0.92      0.94       105
#
#     accuracy                           0.98       630
#    macro avg       0.97      0.96      0.96       630
# weighted avg       0.98      0.98      0.98       630

# %%
model.save("../models/tb_cnn_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("../models/tb_cnn_model.keras")
